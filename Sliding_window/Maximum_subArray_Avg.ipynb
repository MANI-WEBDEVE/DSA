# %%
del sum  # This removes the variable shadowing the built-in
# Or more safely:
import builtins
sum = builtins.sum

# %%
arr=[1,12,-5,-6,50,3]

# %%
len(arr)
# Out:
# 6

# %%
arr[4-k]
# Out:
# 50

# %%
arr[4]
# Out:
# 50

# %%
arr[2-5]
# Out:
# -6

# %%
[2-5]
# Out:
# [-3]

# %%
arr[3]
# Out:
# -6

# %%
k=4
print(arr[:k])
# Out:
# [1, 12, -5, -6]

# %%
arr[k]
# Out:
# 50

# %%
def sub_array_avg(k , nums):
  current_window_sum = sum(nums[:k])
  print(f"window-sum : {current_window_sum}")
  max_sum = current_window_sum

  for i in range(k, len(nums)):
    current_window_sum = current_window_sum - nums[i-k] + nums[i]
    max_sum = max(max_sum, current_window_sum)

  return max_sum / k

sub_array_avg(k,arr)
# Out:
# window-sum : 2
# 12.75

# %%
sum([1,2])
# Out:
# 3
